# %% [markdown]
# # Introduction to Python
# ## Based on the Python Tutorial

# %% [markdown]
# ## Learning Objectives
# - Use Python interactively
# - Work with numbers, text, and lists
# - Write simple programs

# %% [markdown]
# # 1. An Informal Introduction to Python

# %%
print('Hello, World!')

# %% [markdown]
# # 2. Using Python as a Calculator

# %%
2 + 2
50 - 5 * 6
(50 - 5 * 6) / 4
17 // 3
17 % 3
2 ** 10

# %% [markdown]
# ## Exercise: Calculate areas and powers

# %%
# Your code here

# %% [markdown]
# # 3. Numbers

# %%
width = 20
height = 5
area = width * height
area

# %% [markdown]
# # 4. Text

# %%
word = 'Python'
word[0]
word[-1]
word[0:2]

# %% [markdown]
# ## Exercise: Create a greeting with f-strings

# %%
# Your code here

# %% [markdown]
# # 5. Lists

# %%
numbers = [1, 2, 3, 4, 5]
numbers.append(6)
numbers

# %% [markdown]
# # 6. First Steps Towards Programming

# %%
for i in range(5):
    print(i)

# %%
age = 18
if age >= 18:
    print('Adult')
else:
    print('Minor')

# %% [markdown]
# # Final Mini Challenge

# %%
# Ask for a name and print a personalized greeting
