# %% [markdown]
# ## Week 3: Data Structures
# After having learned about **tuples, sets, and dictionaries**, we will now see how to implement that knowledge into exercises.

# %% [markdown]
# #### 3.1 Tuples
# ##### 3.1.1 Basic exercises
#
# 1. Create a tuple `point` containing the coordinates `(3, 7)`. Print its type and length.
# 2. Create a tuple with a single element containing the number `5`. Print it, then print its type. (Hint: what happens if you just write `(5)`?)
# 3. Create an empty tuple two different ways.
# 4. Given `t = (1, 2, 3, 4, 5)`, print:
#    - the first element
#    - the last element (without hard-coding the index `4`)
#    - every other element (`1, 3, 5`)
#    - the tuple reversed

# %%
# Exercise 1

# %%
# Exercise 2

# %%
# Exercise 3

# %%
# Exercise 4

# %% [markdown]
# ##### 3.1.2 Immutability of tuples
# 5. **Tuple packing/unpacking.** Given
#    ```python
#    student = ("Alice", 20, "Computer Science")
#    ```
#    unpack it into three variables `name`, `age`, `major` in a single line,
#    then print a sentence using all three.
#
# 6. **Swap without a temp variable.** Given `a = 10` and `b = 20`, swap their
#    values using tuple packing/unpacking in one line.
#
# 7. **Extended unpacking.** Given
#    ```python
#    scores = (95, 88, 76, 60, 42)
#    ```
#    unpack it so that `first` gets `95`, `last` gets `42`, and `middle` gets
#    the rest as a list. (Hint: research the `*` operator in unpacking.)
#
# 8. **Immutability check.** Try to change the second element of
#    `t = (1, 2, 3)` to `99` (e.g. `t[1] = 99`). Run it, read the error
#    message out loud, and explain in your own words *why* Python raises it.
#
# 9. **Immutable container, mutable contents.** Given
#    ```python
#    record = ("Bob", [85, 90, 78])
#    ```
#    Can you change `record[0]`? Can you change `record[1]`? Try appending a
#    new score to `record[1]` and explain why that works even though tuples
#    are "immutable".

# %%
# Exercise 5

# %%
# Exercise 6

# %%
# Exercise 7

# %%
# Exercise 8

# %%
# Exercise 9

# %% [markdown]
# #### 3.2 Sets
# ##### 3.2.1 Basic operations
# 1. Create a set `fruits` containing `"apple"`, `"banana"`, `"apple"`,
#    `"cherry"`. Print it. What happened to the duplicate?
# 2. Create an empty set correctly. (Hint: `{}` does *not* create an empty
#    set — what does it create instead? Test it with `type({})`.)
# 3. Convert the list `[1, 2, 2, 3, 3, 3]` into a set. What's the resulting
#    length?
# 4. Try creating a set containing a list, e.g. `{1, 2, [3, 4]}`. Read the
#    error. Why can't a list go inside a set, but a tuple can?

# %%
# Exercise 1

# %%
# Exercise 2

# %%
# Exercise 3

# %%
# Exercise 4

# %% [markdown]
# ##### 3.2.2 Set manipulation
#
# 5. Given
#    ```python
#    python_students = {"Ana", "Leo", "Kim", "Sam"}
#    java_students   = {"Kim", "Sam", "Tom", "Eva"}
#    ```
#    compute and print, using both the operator *and* the method form for
#    each (e.g. `|` and `.union()`):
#    - students taking **either** class (union)
#    - students taking **both** classes (intersection)
#    - students taking **Python only** (difference)
#    - students taking **exactly one** of the two classes (symmetric
#      difference)
#
# 6. Check membership: is `"Tom"` in `python_students`? Is `python_students`
#    a subset of `python_students | java_students`? Use `.issubset()` /
#    `<=`.
#
# 7. Add `"Nina"` to `python_students`. Remove `"Leo"` using two different
#    methods (`.remove()` vs `.discard()`) — try removing someone who isn't
#    in the set with each method and explain the difference in behavior.
#
# 8. **Deduplication.** Given a list with repeated values:
#    ```python
#    log_ids = [101, 102, 101, 103, 104, 102, 105]
#    ```
#    Write one line of code to get the unique IDs. Then write one line to get
#    them back as a *sorted list*.
#
# 9. **Set comprehension.** Given `words = ["cat", "dog", "cat", "bird",
#    "dog", "fish"]`, use a set comprehension to build a set of the *lengths*
#    of the unique words.

# %%
# Exercise 5

# %%
# Exercise 6

# %%
# Exercise 7

# %%
# Exercise 8

# %%
# Exercise 9

# %% [markdown]
# #### 3.3. Dictionaries
# ##### 3.3.1 Basic exercises
# 1. Create a dictionary `student` with keys `"name"`, `"age"`, `"major"` and
#    sensible values. Print it, then print its type and length.
# 2. Create an empty dictionary two different ways.
# 3. Given
#    ```python
#    prices = {"apple": 0.5, "banana": 0.3, "cherry": 2.0}
#    ```
#    print the price of `"banana"` two ways: with `[]` indexing and with
#    `.get()`.
# 4. Try accessing `prices["mango"]` with `[]`. Read the error. Now try
#    `prices.get("mango")`, and then `prices.get("mango", "not sold here")`.
#    Explain the difference in behavior between the three.
# 5. Check whether `"apple"` is a key in `prices` using `in`. Then check
#    whether `0.5` is a key in `prices` using `in`. Explain why the second
#    one behaves the way it does — what does `in` check by default on a
#    dict?

# %%
# Exercise 1

# %%
# Exercise 2

# %%
# Exercise 3

# %%
# Exercise 4

# %%
# Exercise 5

# %% [markdown]
# ##### 3.3.2 Iterating over dicts
# 6. Given `prices` from before, write a loop that prints
#     `f"{fruit}: ${price}"` for every item, using `.items()`.
# 7. Write a loop that prints just the keys (using `.keys()`, then again
#     with no method at all — what's the default iteration target of a
#     dict?).
# 8. Write a loop that prints just the values, then compute the total
#     using `sum(prices.values())`.
# 9. **Sequence types resurface.** Convert `prices.items()` into a list of
#     tuples, sort it by price using `sorted(..., key=...)`, and print the
#     cheapest fruit. (This connects back to the tuples lecture: each item
#     *is* a `(key, value)` tuple.)

# %%
# Exercise 6

# %%
# Exercise 7

# %%
# Exercise 8

# %%
# Exercise 9
